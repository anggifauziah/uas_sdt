# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # EDA

# %% [markdown]
# ## Load Dataset

# %%
dataset = pd.read_csv("train.csv")
dataset
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# ## Head and Tail Data

# %%
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %% [markdown]
# ## Shape of Dataset

# %%
dataset.shape
# Out:
# (2000, 21)

# %% [markdown]
# ## Type of Data

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %% [markdown]
# ## Delete Duplicate Data

# %%
print(dataset.shape)
dataset.duplicated().sum()
# Out:
# (2000, 21)
# 0

# %% [markdown]
# ## Missing Value

# %%
dataset.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ## Describe Dataset Statistic

# %%
dataset.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %% [markdown]
# ## Correlation

# %%
cols = dataset.corr()
print(cols['price_range'].sort_values(ascending = False),'\n')
# Out:
# price_range      1.000000
# ram              0.917046
# battery_power    0.200723
# px_width         0.165818
# px_height        0.148858
# int_memory       0.044435
# sc_w             0.038711
# pc               0.033599
# three_g          0.023611
# sc_h             0.022986
# fc               0.021998
# talk_time        0.021859
# blue             0.020573
# wifi             0.018785
# dual_sim         0.017444
# four_g           0.014772
# n_cores          0.004399
# m_dep            0.000853
# clock_speed     -0.006606
# mobile_wt       -0.030302
# touch_screen    -0.030411
# Name: price_range, dtype: float64

# %%
k = 21 #Jumlah variabel
cols = dataset.corr().nlargest(k, 'price_range')['price_range'].index
cm = dataset[cols].corr()
plt.figure(figsize=(30,20))
sns.heatmap(cm, vmax=.8, linewidths=0.01,square=True,annot=True,cmap='viridis',
            linecolor="white",xticklabels = cols.values ,annot_kws = {'size':12},yticklabels = cols.values)
plt.show()

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Data distribution

# %%
feature = ['blue', 'dual_sim', 'four_g', 'three_g', 'touch_screen', 'wifi']

plt.figure(figsize=(20,10))
count = 0

for i in feature:
    myexplode = [0.2, 0]
    
    colors = ['#66b3ff','#ff9999','#ff9999','#ffcc99']
    
    labels = dataset[i].value_counts().index
    sizes = dataset[i].value_counts().values  
    
    plt.subplot(2,3,count+1)
    plt.pie(sizes, labels=labels, explode = myexplode, shadow = True, startangle=90, colors=colors, autopct='%1.1f%%')
    plt.title(f'Distribution of {feature[count]}', color = 'black',fontsize = 15)
    count += 1

# %% [markdown]
# ## No of Phones vs Camera megapixels of front and primary camera

# %%
plt.figure(figsize=(10,6))
dataset['fc'].hist(alpha=0.5,color='blue',label='Front camera')
dataset['pc'].hist(alpha=0.5,color='red',label='Primary camera')
plt.legend()
plt.xlabel('MegaPixels')
# Out:
# Text(0.5, 0, 'MegaPixels')

# %% [markdown]
# # Outliers

# %%
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'price_range', y = 'ram', data = dataset)
plt.subplot(2,2,2)
sns.boxplot(x = 'price_range', y = 'battery_power', data = dataset)
plt.subplot(2,2,3)
sns.boxplot(x = 'price_range', y = 'px_width', data = dataset)
plt.subplot(2,2,4)
sns.boxplot(x = 'price_range', y = 'px_height', data = dataset)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='px_height'>

# %%
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'price_range', y = 'int_memory', data = dataset)
plt.subplot(2,2,2)
sns.boxplot(x = 'price_range', y = 'sc_w', data = dataset)
plt.subplot(2,2,3)
sns.boxplot(x = 'price_range', y = 'pc', data = dataset)
plt.subplot(2,2,4)
sns.boxplot(x = 'price_range', y = 'three_g', data = dataset)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='three_g'>

# %%
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'price_range', y = 'sc_h', data = dataset)
plt.subplot(2,2,2)
sns.boxplot(x = 'price_range', y = 'fc', data = dataset)
plt.subplot(2,2,3)
sns.boxplot(x = 'price_range', y = 'talk_time', data = dataset)
plt.subplot(2,2,4)
sns.boxplot(x = 'price_range', y = 'blue', data = dataset)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='blue'>

# %%
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'price_range', y = 'wifi', data = dataset)
plt.subplot(2,2,2)
sns.boxplot(x = 'price_range', y = 'dual_sim', data = dataset)
plt.subplot(2,2,3)
sns.boxplot(x = 'price_range', y = 'four_g', data = dataset)
plt.subplot(2,2,4)
sns.boxplot(x = 'price_range', y = 'n_cores', data = dataset)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='n_cores'>

# %%
plt.figure(figsize=(20,15))
sns.set_style('darkgrid')
plt.subplot(2,2,1)
sns.boxplot(x = 'price_range', y = 'm_dep', data = dataset)
plt.subplot(2,2,2)
sns.boxplot(x = 'price_range', y = 'clock_speed', data = dataset)
plt.subplot(2,2,3)
sns.boxplot(x = 'price_range', y = 'mobile_wt', data = dataset)
plt.subplot(2,2,4)
sns.boxplot(x = 'price_range', y = 'touch_screen', data = dataset)
# Out:
# <AxesSubplot:xlabel='price_range', ylabel='touch_screen'>
